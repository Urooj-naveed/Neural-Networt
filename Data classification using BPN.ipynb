# %% [markdown]
# <a href="https://colab.research.google.com/github/Urooj-naveed/Neural-Networt/blob/main/Data%20classification%20using%20BPN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New section

# %% [markdown]
# # New section

# %%
from scipy.sparse import coo_matrix
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import preprocessing
from sklearn.metrics import plot_confusion_matrix, confusion_matrix
import seaborn as sns

n_data_points = 2000

def regionC1(rad, thk, b, a):
  c1 = np.array([(rad+thk)/2, 0])

  # We use random radius in the interval [rad, rad+thk]
  # and random angles from 0 to pi radians.
  r1 = np.random.rand(n_data_points)*thk+rad
  a1 = np.random.rand(n_data_points)*np.pi+np.pi/2
  #conversion to cartesian:
  p1 = np.array((r1*np.cos(a1)+a, r1*np.sin(a1)))
  x1, y1 = (p1[0] - c1[0], p1[1] - c1[1])
  
  #plt.scatter(x1, y1, marker='.', linewidths=0.1)

  #creating DataFrames
  return x1, y1
  
def regionC2(rad, thk, b, a):
  c2 =  np.array([-(rad+thk)/2, 0])
  r2 = np.random.rand(n_data_points)*thk+rad
  a2 = np.random.rand(n_data_points)*np.pi-np.pi/2
  p2 = np.array((r2*np.cos(a2)+b, r2*np.sin(a2)-1))
  x2, y2 = (p2[0] - c2[0], p2[1] - c2[1])
  
  #plt.scatter(x2, y2, marker='.', linewidths=0.1)
  return x2, y2

if __name__ == '__main__':

 C1 = regionC1(1, 1, -1,1)
 C2 = regionC2(1, 1, -1,1)
 Cg = regionC2(0, 1, -0.5, 0.5)
 Cr = regionC1(0, 1, -0.5, 0.5)
 ConC1 = np.concatenate((C1, Cg), axis=1)
 ConC2 = np.concatenate((C2, Cr), axis=1)
 
 #print (ConC1, ConC2)
 #creating DataFrames
 data_C1 = pd.DataFrame(ConC1).T
 data_C1.columns = ['x1', 'y1']
 data_C1['class'] = '0'
 #print (data_C1)
 
 data_C2 = pd.DataFrame(ConC2).T
 data_C2.columns = ['x1', 'y1']
 data_C2['class'] = '1'
 
 #print (data_C2)

 msk1 = np.random.rand(len(data_C1)) < 0.8
 trainC1 = data_C1[msk1]
 testC1 = data_C1[~msk1]
 msk3 = np.random.rand(len(testC1)) < 0.2
 predictC1 = testC1[~msk3]
 print(predictC1)

 msk2 = np.random.rand(len(data_C2)) < 0.8
 trainC2 = data_C2[msk2]
 testC2 = data_C2[~msk2]
 msk4 = np.random.rand(len(testC2)) < 0.2
 predictC2 = testC2[~msk4]
 print(predictC2)
 
 #filtering data
 train_dataC1 = trainC1[['x1','y1','class']]
 test_dataC1 = testC1[['x1','y1','class']]
 pred_dataC1 = predictC1[['x1','y1','class']]
 train_dataC2 = trainC2[['x1','y1','class']]
 test_dataC2 = testC2[['x1','y1','class']]
 pred_dataC2 = predictC2[['x1','y1','class']]
    
 train_data = pd.concat([train_dataC1, train_dataC2])
 test_data = pd.concat([test_dataC1, test_dataC2])
 pred_data = pd.concat([pred_dataC1, pred_dataC2])

 #data splitting
 lb = preprocessing.LabelEncoder()
 trainX= train_data[['x1','y1']].values
 trainY= train_data[['class']].values
 train_Y= lb.fit_transform(trainY)
 #print(trainX)
 #print(train_dataC1.dtypes)
 testX= test_data[['x1','y1']].values
 testY= test_data[['class']].values
 test_Y= lb.fit_transform(testY)
 predX= pred_data[['x1','y1']].values
 predY= pred_data[['class']].values
 pred_Y= lb.fit_transform(predY)

 model = keras.Sequential()
 model.add(layers.Dense(10, activation="relu", name="layer1"))
 model.add(layers.Dense(5, activation="relu", name="layer2"))
 model.add(layers.Dense(1, activation="sigmoid", name="layer3"))
 
 optimizer = keras.optimizers.Adam(lr=0.1)
 model.compile(optimizer, loss='binary_crossentropy', metrics=['accuracy'])
 history = model.fit(trainX, train_Y, epochs=100, batch_size=32, validation_data=(testX,test_Y))
 print("Evaluate model on test data")
 results = model.evaluate(testX, test_Y, batch_size=128)
 print("test loss, test acc:", results)

# summarize history for accuracy
 plt.plot(history.history['accuracy'])
 plt.plot(history.history['val_accuracy'])
 plt.title('model accuracy')
 plt.ylabel('accuracy')
 plt.xlabel('epoch')
 plt.legend(['train', 'test'], loc='upper left')
 plt.show()

 predictions = model.predict(predX)
 predictions = [1 if p[0] >= 0.5 else 0 for p in predictions]
 cm = confusion_matrix(pred_Y, predictions)
 sns.heatmap(cm, annot=True, cmap="Blues", fmt="d")
 plt.xlabel("Predicted Labels")
 plt.ylabel("True Labels")
 plt.title("Confusion Matrix")
 plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
#             x1        y1 class
# 0    -0.701363 -1.711962     0
# 7    -1.101435  0.471253     0
# 8    -1.175918 -1.307611     0
# 15   -1.938436 -0.124953     0
# 23   -0.543596 -0.897553     0
# ...        ...       ...   ...
# 3972  0.236968 -1.190824     0
# 3978  0.078582 -1.023373     0
# 3990  0.012895 -1.573567     0
# 3998  0.174603 -1.269183     0
# 3999  0.037281 -1.708484     0
#
# [656 rows x 3 columns]
#             x1        y1 class
# 1     0.293044  0.046992     1
# 10    1.905400 -0.730763     1
# 17    0.757217 -2.636171     1
# 19    1.309646 -0.487444     1
# 27    1.111442 -2.380961     1
# ...        ...       ...   ...
# 3984 -0.948763  0.268648     1
# 3985 -0.171725 -0.468379     1
# 3987 -0.325241 -0.454711     1
# 3990 -0.620301 -0.107878     1
# 3999 -0.015040 -0.292575     1
#
# [633 rows x 3 columns]
# Epoch 1/100
# 200/200 [==============================] - 3s 5ms/step - loss: 0.6750 - accuracy: 0.4743 - val_loss: 0.6440 - val_accuracy: 0.5659
# Epoch 2/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5915 - accuracy: 0.6884 - val_loss: 0.5574 - val_accuracy: 0.7008
# Epoch 3/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5100 - accuracy: 0.7471 - val_loss: 0.4742 - val_accuracy: 0.7795
# Epoch 4/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.4249 - accuracy: 0.8112 - val_loss: 0.3819 - val_accuracy: 0.8457
# Epoch 5/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3399 - accuracy: 0.8664 - val_loss: 0.3018 - val_accuracy: 0.8801
# Epoch 6/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2798 - accuracy: 0.8992 - val_loss: 0.2540 - val_accuracy: 0.9032
# Epoch 7/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2447 - accuracy: 0.9145 - val_loss: 0.2252 - val_accuracy: 0.9126
# Epoch 8/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2207 - accuracy: 0.9225 - val_loss: 0.2055 - val_accuracy: 0.9250
# Epoch 9/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2036 - accuracy: 0.9305 - val_loss: 0.1914 - val_accuracy: 0.9325
# Epoch 10/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1896 - accuracy: 0.9351 - val_loss: 0.1789 - val_accuracy: 0.9400
# Epoch 11/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1789 - accuracy: 0.9403 - val_loss: 0.1685 - val_accuracy: 0.9407
# Epoch 12/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1691 - accuracy: 0.9455 - val_loss: 0.1594 - val_accuracy: 0.9469
# Epoch 13/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1612 - accuracy: 0.9486 - val_loss: 0.1565 - val_accuracy: 0.9394
# Epoch 14/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.1541 - accuracy: 0.9497 - val_loss: 0.1467 - val_accuracy: 0.9469
# Epoch 15/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1474 - accuracy: 0.9547 - val_loss: 0.1411 - val_accuracy: 0.9563
# Epoch 16/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1417 - accuracy: 0.9569 - val_loss: 0.1355 - val_accuracy: 0.9482
# Epoch 17/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1368 - accuracy: 0.9566 - val_loss: 0.1305 - val_accuracy: 0.9532
# Epoch 18/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1321 - accuracy: 0.9597 - val_loss: 0.1271 - val_accuracy: 0.9500
# Epoch 19/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1276 - accuracy: 0.9583 - val_loss: 0.1221 - val_accuracy: 0.9544
# Epoch 20/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1236 - accuracy: 0.9600 - val_loss: 0.1187 - val_accuracy: 0.9563
# Epoch 21/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.1202 - accuracy: 0.9612 - val_loss: 0.1158 - val_accuracy: 0.9550
# Epoch 22/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.1163 - accuracy: 0.9602 - val_loss: 0.1129 - val_accuracy: 0.9563
# Epoch 23/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.1133 - accuracy: 0.9612 - val_loss: 0.1102 - val_accuracy: 0.9569
# Epoch 24/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1101 - accuracy: 0.9628 - val_loss: 0.1085 - val_accuracy: 0.9625
# Epoch 25/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1072 - accuracy: 0.9622 - val_loss: 0.1051 - val_accuracy: 0.9606
# Epoch 26/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1046 - accuracy: 0.9642 - val_loss: 0.1036 - val_accuracy: 0.9613
# Epoch 27/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1024 - accuracy: 0.9655 - val_loss: 0.1026 - val_accuracy: 0.9606
# Epoch 28/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1003 - accuracy: 0.9656 - val_loss: 0.0982 - val_accuracy: 0.9650
# Epoch 29/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0982 - accuracy: 0.9662 - val_loss: 0.0975 - val_accuracy: 0.9600
# Epoch 30/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0965 - accuracy: 0.9661 - val_loss: 0.0938 - val_accuracy: 0.9700
# Epoch 31/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0937 - accuracy: 0.9678 - val_loss: 0.0923 - val_accuracy: 0.9644
# Epoch 32/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0917 - accuracy: 0.9691 - val_loss: 0.0901 - val_accuracy: 0.9719
# Epoch 33/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0896 - accuracy: 0.9703 - val_loss: 0.0887 - val_accuracy: 0.9669
# Epoch 34/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0883 - accuracy: 0.9691 - val_loss: 0.0870 - val_accuracy: 0.9725
# Epoch 35/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0867 - accuracy: 0.9706 - val_loss: 0.0858 - val_accuracy: 0.9688
# Epoch 36/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0847 - accuracy: 0.9709 - val_loss: 0.0849 - val_accuracy: 0.9656
# Epoch 37/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0836 - accuracy: 0.9712 - val_loss: 0.0822 - val_accuracy: 0.9700
# Epoch 38/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0819 - accuracy: 0.9720 - val_loss: 0.0807 - val_accuracy: 0.9713
# Epoch 39/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0803 - accuracy: 0.9722 - val_loss: 0.0802 - val_accuracy: 0.9713
# Epoch 40/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0784 - accuracy: 0.9759 - val_loss: 0.0783 - val_accuracy: 0.9688
# Epoch 41/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0770 - accuracy: 0.9739 - val_loss: 0.0772 - val_accuracy: 0.9706
# Epoch 42/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0758 - accuracy: 0.9753 - val_loss: 0.0761 - val_accuracy: 0.9719
# Epoch 43/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0743 - accuracy: 0.9753 - val_loss: 0.0799 - val_accuracy: 0.9638
# Epoch 44/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.0728 - accuracy: 0.9750 - val_loss: 0.0743 - val_accuracy: 0.9725
# Epoch 45/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0713 - accuracy: 0.9769 - val_loss: 0.0749 - val_accuracy: 0.9688
# Epoch 46/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0700 - accuracy: 0.9766 - val_loss: 0.0708 - val_accuracy: 0.9750
# Epoch 47/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0695 - accuracy: 0.9772 - val_loss: 0.0711 - val_accuracy: 0.9725
# Epoch 48/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0674 - accuracy: 0.9777 - val_loss: 0.0680 - val_accuracy: 0.9763
# Epoch 49/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0669 - accuracy: 0.9783 - val_loss: 0.0676 - val_accuracy: 0.9725
# Epoch 50/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0655 - accuracy: 0.9786 - val_loss: 0.0690 - val_accuracy: 0.9706
# Epoch 51/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.0644 - accuracy: 0.9789 - val_loss: 0.0669 - val_accuracy: 0.9769
# Epoch 52/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0635 - accuracy: 0.9789 - val_loss: 0.0654 - val_accuracy: 0.9756
# Epoch 53/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0627 - accuracy: 0.9798 - val_loss: 0.0654 - val_accuracy: 0.9719
# Epoch 54/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0613 - accuracy: 0.9808 - val_loss: 0.0616 - val_accuracy: 0.9788
# Epoch 55/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0603 - accuracy: 0.9805 - val_loss: 0.0604 - val_accuracy: 0.9775
# Epoch 56/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0596 - accuracy: 0.9805 - val_loss: 0.0594 - val_accuracy: 0.9775
# Epoch 57/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0588 - accuracy: 0.9812 - val_loss: 0.0599 - val_accuracy: 0.9794
# Epoch 58/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0576 - accuracy: 0.9817 - val_loss: 0.0581 - val_accuracy: 0.9794
# Epoch 59/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0578 - accuracy: 0.9808 - val_loss: 0.0573 - val_accuracy: 0.9769
# Epoch 60/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0563 - accuracy: 0.9808 - val_loss: 0.0559 - val_accuracy: 0.9800
# Epoch 61/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0558 - accuracy: 0.9825 - val_loss: 0.0572 - val_accuracy: 0.9800
# Epoch 62/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0550 - accuracy: 0.9816 - val_loss: 0.0544 - val_accuracy: 0.9813
# Epoch 63/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0546 - accuracy: 0.9831 - val_loss: 0.0556 - val_accuracy: 0.9806
# Epoch 64/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0538 - accuracy: 0.9820 - val_loss: 0.0539 - val_accuracy: 0.9825
# Epoch 65/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0530 - accuracy: 0.9828 - val_loss: 0.0539 - val_accuracy: 0.9763
# Epoch 66/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0523 - accuracy: 0.9827 - val_loss: 0.0516 - val_accuracy: 0.9831
# Epoch 67/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0514 - accuracy: 0.9837 - val_loss: 0.0538 - val_accuracy: 0.9781
# Epoch 68/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0512 - accuracy: 0.9836 - val_loss: 0.0512 - val_accuracy: 0.9838
# Epoch 69/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0506 - accuracy: 0.9831 - val_loss: 0.0520 - val_accuracy: 0.9794
# Epoch 70/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0505 - accuracy: 0.9837 - val_loss: 0.0490 - val_accuracy: 0.9844
# Epoch 71/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0496 - accuracy: 0.9842 - val_loss: 0.0499 - val_accuracy: 0.9844
# Epoch 72/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0494 - accuracy: 0.9831 - val_loss: 0.0484 - val_accuracy: 0.9844
# Epoch 73/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0486 - accuracy: 0.9839 - val_loss: 0.0500 - val_accuracy: 0.9813
# Epoch 74/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0482 - accuracy: 0.9839 - val_loss: 0.0504 - val_accuracy: 0.9819
# Epoch 75/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0476 - accuracy: 0.9841 - val_loss: 0.0486 - val_accuracy: 0.9838
# Epoch 76/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0474 - accuracy: 0.9847 - val_loss: 0.0475 - val_accuracy: 0.9850
# Epoch 77/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0469 - accuracy: 0.9848 - val_loss: 0.0464 - val_accuracy: 0.9856
# Epoch 78/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0464 - accuracy: 0.9844 - val_loss: 0.0470 - val_accuracy: 0.9850
# Epoch 79/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0464 - accuracy: 0.9852 - val_loss: 0.0480 - val_accuracy: 0.9825
# Epoch 80/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0458 - accuracy: 0.9852 - val_loss: 0.0462 - val_accuracy: 0.9844
# Epoch 81/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0456 - accuracy: 0.9850 - val_loss: 0.0459 - val_accuracy: 0.9856
# Epoch 82/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0453 - accuracy: 0.9853 - val_loss: 0.0444 - val_accuracy: 0.9850
# Epoch 83/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0444 - accuracy: 0.9862 - val_loss: 0.0442 - val_accuracy: 0.9850
# Epoch 84/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0448 - accuracy: 0.9837 - val_loss: 0.0449 - val_accuracy: 0.9850
# Epoch 85/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0443 - accuracy: 0.9856 - val_loss: 0.0463 - val_accuracy: 0.9819
# Epoch 86/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0434 - accuracy: 0.9859 - val_loss: 0.0453 - val_accuracy: 0.9844
# Epoch 87/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0436 - accuracy: 0.9855 - val_loss: 0.0427 - val_accuracy: 0.9869
# Epoch 88/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0432 - accuracy: 0.9856 - val_loss: 0.0438 - val_accuracy: 0.9850
# Epoch 89/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0430 - accuracy: 0.9847 - val_loss: 0.0414 - val_accuracy: 0.9869
# Epoch 90/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0426 - accuracy: 0.9852 - val_loss: 0.0418 - val_accuracy: 0.9881
# Epoch 91/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0425 - accuracy: 0.9855 - val_loss: 0.0428 - val_accuracy: 0.9850
# Epoch 92/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.0420 - accuracy: 0.9858 - val_loss: 0.0425 - val_accuracy: 0.9863
# Epoch 93/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0413 - accuracy: 0.9866 - val_loss: 0.0419 - val_accuracy: 0.9856
# Epoch 94/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0415 - accuracy: 0.9864 - val_loss: 0.0430 - val_accuracy: 0.9856
# Epoch 95/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0409 - accuracy: 0.9866 - val_loss: 0.0435 - val_accuracy: 0.9838
# Epoch 96/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0406 - accuracy: 0.9866 - val_loss: 0.0408 - val_accuracy: 0.9869
# Epoch 97/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0409 - accuracy: 0.9859 - val_loss: 0.0393 - val_accuracy: 0.9869
# Epoch 98/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0403 - accuracy: 0.9859 - val_loss: 0.0418 - val_accuracy: 0.9856
# Epoch 99/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0398 - accuracy: 0.9858 - val_loss: 0.0397 - val_accuracy: 0.9850
# Epoch 100/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0395 - accuracy: 0.9866 - val_loss: 0.0387 - val_accuracy: 0.9881
# Evaluate model on test data
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 0.9881
# test loss, test acc: [0.03874891623854637, 0.9881324172019958]
# 41/41 [==============================] - 0s 2ms/step

# %%
from scipy.sparse import coo_matrix
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import preprocessing
from sklearn.metrics import plot_confusion_matrix, confusion_matrix
import seaborn as sns

def generate_regionC1(rad, thk, b, a, n_data_points):
    c1 = np.array([(rad + thk) / 2, 0])

    r1 = np.random.rand(n_data_points) * thk + rad
    a1 = np.random.rand(n_data_points) * np.pi + np.pi / 2

    p1 = np.array((r1 * np.cos(a1) + a, r1 * np.sin(a1)))
    x1, y1 = (p1[0] - c1[0], p1[1] - c1[1])

    return x1, y1
  
def generate_regionC2(rad, thk, b, a, n_data_points):
    c2 = np.array([-(rad + thk) / 2, 0])
    r2 = np.random.rand(n_data_points) * thk + rad
    a2 = np.random.rand(n_data_points) * np.pi - np.pi / 2
    p2 = np.array((r2 * np.cos(a2) + b, r2 * np.sin(a2) - 1))
    x2, y2 = (p2[0] - c2[0], p2[1] - c2[1])

    return x2, y2

def get_and_process_data():
    n_data_points = 2000

    C1 = generate_regionC1(1, 1, -1, 1, n_data_points)
    C2 = generate_regionC2(1, 1, -1, 1, n_data_points)
    Cg = generate_regionC2(0, 1, -0.5, 0.5, n_data_points)
    Cr = generate_regionC1(0, 1, -0.5, 0.5, n_data_points)
    ConC1 = np.concatenate((C1, Cg), axis=1)
    ConC2 = np.concatenate((C2, Cr), axis=1)

    data_C1 = pd.DataFrame(ConC1).T
    data_C1.columns = ['x1', 'y1']
    data_C1['class'] = '0'

    data_C2 = pd.DataFrame(ConC2).T
    data_C2.columns = ['x1', 'y1']
    data_C2['class'] = '1'
   

    train_dataC1, test_dataC1, pred_dataC1 = split_data(data_C1)
    train_dataC2, test_dataC2, pred_dataC2 = split_data(data_C2)

    train_data = pd.concat([train_dataC1, train_dataC2])
    test_data = pd.concat([test_dataC1, test_dataC2])
    pred_data = pd.concat([pred_dataC1, pred_dataC2])
  
    X_train = train_data[['x1', 'y1']].values
    y_train = train_data['class'].values.astype(int)

    X_test = test_data[['x1', 'y1']].values
    y_test = test_data['class'].values.astype(int)

    X_pred = pred_data[['x1', 'y1']].values
    Y_pred = pred_data[['class']].astype(int).values

    scaler = preprocessing.StandardScaler().fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    X_pred = scaler.transform(X_pred)

    return X_train, y_train, X_test, y_test, X_pred, Y_pred

def split_data(data):
  train_data, test_data = train_test_split(data, test_size=0.2)
  train_data = train_data.reset_index(drop=True)
  test_data = test_data.reset_index(drop=True)
  pred_data = data.loc[~data.index.isin(train_data.index) & ~data.index.isin(test_data.index)]
  return train_data, test_data, pred_data

def create_model():
  model = Sequential([
  Dense(5, activation='relu', input_shape=(2,)),
  Dense(50, activation='relu'),
  Dense(1, activation='sigmoid'),])
  optimizer = keras.optimizers.Adam(beta_1=0.9)
  model.compile(optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  return model

def train_and_evaluate(X_train, y_train, X_test, y_test, X_pred, Y_pred):
  model = create_model()
  history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
  test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
  print("Test accuracy: {test_acc}")
  print("\n Evaluate model on test data")
  results = model.evaluate(X_test, y_test, batch_size=128)
  print("test loss, test acc:", results)

# summarize history for accuracy
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  y_pred = model.predict(X_pred).round()
  predictions = [1 if p[0] >= 0.5 else 0 for p in y_pred]
  cm = confusion_matrix( Y_pred, predictions)
  sns.heatmap(cm, annot=True, cmap="Blues", fmt="d")
  plt.xlabel("Predicted Labels")
  plt.ylabel("True Labels")
  plt.title("Confusion Matrix")
  plt.show()

def main():
  X_train, y_train, X_test, y_test, X_pred, Y_pred = get_and_process_data()
  train_and_evaluate(X_train, y_train, X_test, y_test, X_pred, Y_pred)

if __name__ == '__main__':
  main()
# Out:
# Epoch 1/100
# 200/200 [==============================] - 3s 3ms/step - loss: 0.6252 - accuracy: 0.6652 - val_loss: 0.5599 - val_accuracy: 0.7081
# Epoch 2/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.5109 - accuracy: 0.7391 - val_loss: 0.4535 - val_accuracy: 0.8125
# Epoch 3/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4026 - accuracy: 0.8327 - val_loss: 0.3474 - val_accuracy: 0.8775
# Epoch 4/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3149 - accuracy: 0.8797 - val_loss: 0.2780 - val_accuracy: 0.9050
# Epoch 5/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2624 - accuracy: 0.8966 - val_loss: 0.2384 - val_accuracy: 0.9181
# Epoch 6/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2281 - accuracy: 0.9131 - val_loss: 0.2132 - val_accuracy: 0.9281
# Epoch 7/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2040 - accuracy: 0.9223 - val_loss: 0.1914 - val_accuracy: 0.9356
# Epoch 8/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1859 - accuracy: 0.9312 - val_loss: 0.1755 - val_accuracy: 0.9388
# Epoch 9/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1703 - accuracy: 0.9355 - val_loss: 0.1602 - val_accuracy: 0.9463
# Epoch 10/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1570 - accuracy: 0.9428 - val_loss: 0.1461 - val_accuracy: 0.9500
# Epoch 11/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1449 - accuracy: 0.9469 - val_loss: 0.1361 - val_accuracy: 0.9538
# Epoch 12/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1334 - accuracy: 0.9508 - val_loss: 0.1254 - val_accuracy: 0.9606
# Epoch 13/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1241 - accuracy: 0.9542 - val_loss: 0.1230 - val_accuracy: 0.9588
# Epoch 14/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1143 - accuracy: 0.9605 - val_loss: 0.1094 - val_accuracy: 0.9663
# Epoch 15/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1059 - accuracy: 0.9647 - val_loss: 0.1061 - val_accuracy: 0.9675
# Epoch 16/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1000 - accuracy: 0.9683 - val_loss: 0.0974 - val_accuracy: 0.9694
# Epoch 17/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0930 - accuracy: 0.9702 - val_loss: 0.0912 - val_accuracy: 0.9731
# Epoch 18/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0874 - accuracy: 0.9733 - val_loss: 0.0866 - val_accuracy: 0.9775
# Epoch 19/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0819 - accuracy: 0.9756 - val_loss: 0.0847 - val_accuracy: 0.9744
# Epoch 20/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0774 - accuracy: 0.9781 - val_loss: 0.0795 - val_accuracy: 0.9800
# Epoch 21/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0735 - accuracy: 0.9784 - val_loss: 0.0756 - val_accuracy: 0.9806
# Epoch 22/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0702 - accuracy: 0.9798 - val_loss: 0.0732 - val_accuracy: 0.9819
# Epoch 23/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0674 - accuracy: 0.9798 - val_loss: 0.0721 - val_accuracy: 0.9794
# Epoch 24/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0641 - accuracy: 0.9806 - val_loss: 0.0686 - val_accuracy: 0.9812
# Epoch 25/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0620 - accuracy: 0.9817 - val_loss: 0.0671 - val_accuracy: 0.9806
# Epoch 26/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0596 - accuracy: 0.9823 - val_loss: 0.0661 - val_accuracy: 0.9806
# Epoch 27/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0575 - accuracy: 0.9820 - val_loss: 0.0628 - val_accuracy: 0.9825
# Epoch 28/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0558 - accuracy: 0.9842 - val_loss: 0.0599 - val_accuracy: 0.9862
# Epoch 29/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0543 - accuracy: 0.9841 - val_loss: 0.0595 - val_accuracy: 0.9819
# Epoch 30/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0529 - accuracy: 0.9847 - val_loss: 0.0573 - val_accuracy: 0.9825
# Epoch 31/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0511 - accuracy: 0.9842 - val_loss: 0.0605 - val_accuracy: 0.9781
# Epoch 32/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0502 - accuracy: 0.9844 - val_loss: 0.0559 - val_accuracy: 0.9825
# Epoch 33/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0488 - accuracy: 0.9853 - val_loss: 0.0543 - val_accuracy: 0.9856
# Epoch 34/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0477 - accuracy: 0.9859 - val_loss: 0.0524 - val_accuracy: 0.9869
# Epoch 35/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0465 - accuracy: 0.9869 - val_loss: 0.0545 - val_accuracy: 0.9825
# Epoch 36/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0455 - accuracy: 0.9872 - val_loss: 0.0522 - val_accuracy: 0.9812
# Epoch 37/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0444 - accuracy: 0.9872 - val_loss: 0.0501 - val_accuracy: 0.9850
# Epoch 38/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0434 - accuracy: 0.9877 - val_loss: 0.0511 - val_accuracy: 0.9831
# Epoch 39/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0430 - accuracy: 0.9877 - val_loss: 0.0484 - val_accuracy: 0.9856
# Epoch 40/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0420 - accuracy: 0.9869 - val_loss: 0.0503 - val_accuracy: 0.9850
# Epoch 41/100
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0418 - accuracy: 0.9877 - val_loss: 0.0487 - val_accuracy: 0.9844
# Epoch 42/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0412 - accuracy: 0.9873 - val_loss: 0.0508 - val_accuracy: 0.9831
# Epoch 43/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0403 - accuracy: 0.9873 - val_loss: 0.0482 - val_accuracy: 0.9850
# Epoch 44/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0393 - accuracy: 0.9881 - val_loss: 0.0463 - val_accuracy: 0.9862
# Epoch 45/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0386 - accuracy: 0.9889 - val_loss: 0.0441 - val_accuracy: 0.9887
# Epoch 46/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0381 - accuracy: 0.9884 - val_loss: 0.0428 - val_accuracy: 0.9900
# Epoch 47/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0377 - accuracy: 0.9881 - val_loss: 0.0451 - val_accuracy: 0.9856
# Epoch 48/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0369 - accuracy: 0.9891 - val_loss: 0.0443 - val_accuracy: 0.9887
# Epoch 49/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0369 - accuracy: 0.9895 - val_loss: 0.0445 - val_accuracy: 0.9869
# Epoch 50/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0368 - accuracy: 0.9873 - val_loss: 0.0425 - val_accuracy: 0.9862
# Epoch 51/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0354 - accuracy: 0.9887 - val_loss: 0.0427 - val_accuracy: 0.9856
# Epoch 52/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0354 - accuracy: 0.9898 - val_loss: 0.0405 - val_accuracy: 0.9887
# Epoch 53/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0342 - accuracy: 0.9892 - val_loss: 0.0397 - val_accuracy: 0.9906
# Epoch 54/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0342 - accuracy: 0.9900 - val_loss: 0.0390 - val_accuracy: 0.9900
# Epoch 55/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0338 - accuracy: 0.9902 - val_loss: 0.0500 - val_accuracy: 0.9787
# Epoch 56/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0343 - accuracy: 0.9889 - val_loss: 0.0378 - val_accuracy: 0.9912
# Epoch 57/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0336 - accuracy: 0.9891 - val_loss: 0.0387 - val_accuracy: 0.9894
# Epoch 58/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0328 - accuracy: 0.9902 - val_loss: 0.0391 - val_accuracy: 0.9894
# Epoch 59/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0324 - accuracy: 0.9902 - val_loss: 0.0382 - val_accuracy: 0.9900
# Epoch 60/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0321 - accuracy: 0.9900 - val_loss: 0.0373 - val_accuracy: 0.9900
# Epoch 61/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0315 - accuracy: 0.9897 - val_loss: 0.0375 - val_accuracy: 0.9887
# Epoch 62/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0317 - accuracy: 0.9912 - val_loss: 0.0363 - val_accuracy: 0.9906
# Epoch 63/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0311 - accuracy: 0.9898 - val_loss: 0.0389 - val_accuracy: 0.9881
# Epoch 64/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0308 - accuracy: 0.9906 - val_loss: 0.0394 - val_accuracy: 0.9837
# Epoch 65/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 0.9906 - val_loss: 0.0388 - val_accuracy: 0.9881
# Epoch 66/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0309 - accuracy: 0.9902 - val_loss: 0.0355 - val_accuracy: 0.9881
# Epoch 67/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0300 - accuracy: 0.9914 - val_loss: 0.0358 - val_accuracy: 0.9887
# Epoch 68/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0300 - accuracy: 0.9898 - val_loss: 0.0340 - val_accuracy: 0.9906
# Epoch 69/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 0.9911 - val_loss: 0.0373 - val_accuracy: 0.9875
# Epoch 70/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0289 - accuracy: 0.9902 - val_loss: 0.0416 - val_accuracy: 0.9794
# Epoch 71/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0298 - accuracy: 0.9902 - val_loss: 0.0362 - val_accuracy: 0.9862
# Epoch 72/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0289 - accuracy: 0.9898 - val_loss: 0.0341 - val_accuracy: 0.9881
# Epoch 73/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0286 - accuracy: 0.9920 - val_loss: 0.0332 - val_accuracy: 0.9900
# Epoch 74/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0284 - accuracy: 0.9908 - val_loss: 0.0328 - val_accuracy: 0.9925
# Epoch 75/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0280 - accuracy: 0.9914 - val_loss: 0.0328 - val_accuracy: 0.9900
# Epoch 76/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0277 - accuracy: 0.9917 - val_loss: 0.0317 - val_accuracy: 0.9912
# Epoch 77/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0278 - accuracy: 0.9911 - val_loss: 0.0346 - val_accuracy: 0.9887
# Epoch 78/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0279 - accuracy: 0.9916 - val_loss: 0.0322 - val_accuracy: 0.9912
# Epoch 79/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0271 - accuracy: 0.9920 - val_loss: 0.0318 - val_accuracy: 0.9894
# Epoch 80/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0268 - accuracy: 0.9911 - val_loss: 0.0351 - val_accuracy: 0.9881
# Epoch 81/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0265 - accuracy: 0.9923 - val_loss: 0.0315 - val_accuracy: 0.9925
# Epoch 82/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0268 - accuracy: 0.9920 - val_loss: 0.0313 - val_accuracy: 0.9906
# Epoch 83/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0264 - accuracy: 0.9920 - val_loss: 0.0304 - val_accuracy: 0.9919
# Epoch 84/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0262 - accuracy: 0.9933 - val_loss: 0.0308 - val_accuracy: 0.9912
# Epoch 85/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0264 - accuracy: 0.9916 - val_loss: 0.0306 - val_accuracy: 0.9900
# Epoch 86/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0266 - accuracy: 0.9908 - val_loss: 0.0298 - val_accuracy: 0.9900
# Epoch 87/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0261 - accuracy: 0.9908 - val_loss: 0.0319 - val_accuracy: 0.9919
# Epoch 88/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.0259 - accuracy: 0.9920 - val_loss: 0.0298 - val_accuracy: 0.9900
# Epoch 89/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0260 - accuracy: 0.9923 - val_loss: 0.0300 - val_accuracy: 0.9912
# Epoch 90/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9923 - val_loss: 0.0301 - val_accuracy: 0.9900
# Epoch 91/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0254 - accuracy: 0.9914 - val_loss: 0.0298 - val_accuracy: 0.9919
# Epoch 92/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0255 - accuracy: 0.9912 - val_loss: 0.0287 - val_accuracy: 0.9925
# Epoch 93/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0253 - accuracy: 0.9930 - val_loss: 0.0290 - val_accuracy: 0.9900
# Epoch 94/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0257 - accuracy: 0.9905 - val_loss: 0.0282 - val_accuracy: 0.9919
# Epoch 95/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0252 - accuracy: 0.9923 - val_loss: 0.0302 - val_accuracy: 0.9912
# Epoch 96/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0246 - accuracy: 0.9923 - val_loss: 0.0287 - val_accuracy: 0.9931
# Epoch 97/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0245 - accuracy: 0.9933 - val_loss: 0.0300 - val_accuracy: 0.9900
# Epoch 98/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0240 - accuracy: 0.9927 - val_loss: 0.0318 - val_accuracy: 0.9894
# Epoch 99/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0246 - accuracy: 0.9922 - val_loss: 0.0281 - val_accuracy: 0.9906
# Epoch 100/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0243 - accuracy: 0.9917 - val_loss: 0.0300 - val_accuracy: 0.9919
# 50/50 - 0s - loss: 0.0300 - accuracy: 0.9919 - 104ms/epoch - 2ms/step
# Test accuracy: {test_acc}
#
#  Evaluate model on test data
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 0.9919
# test loss, test acc: [0.029957983642816544, 0.9918749928474426]
# 50/50 [==============================] - 0s 2ms/step
